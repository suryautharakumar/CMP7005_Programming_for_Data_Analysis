# %% [markdown]
# <a href="https://colab.research.google.com/github/suryautharakumar/CMP7005_Programming_for_Data_Analysis/blob/main/CMP7005_Programming_for_Data_Analysis_Final_Assessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load the Drive helper and mount
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Colab/CMP7005_Programming_for_Data Analysis/Assessment_Data'
# Out:
# /content/drive/MyDrive/Colab/CMP7005_Programming_for_Data Analysis/Assessment_Data

# %%
# %ls
# Out:
# Ahmedabad_data.csv       Chennai_data.csv     Kochi_data.csv
# Aizawl_data.csv          Coimbatore_data.csv  Kolkata_data.csv
# all_cities_combined.csv  Delhi_data.csv       Lucknow_data.csv
# Amaravati_data.csv       Ernakulam_data.csv   Mumbai_data.csv
# Amritsar_data.csv        Gurugram_data.csv    Patna_data.csv
# Bengaluru_data.csv       Guwahati_data.csv    Shillong_data.csv
# Bhopal_data.csv          Hyderabad_data.csv   Talcher_data.csv
# Brajrajnagar_data.csv    Jaipur_data.csv      Thiruvananthapuram_data.csv
# Chandigarh_data.csv      Jorapokhar_data.csv  Visakhapatnam_data.csv

# %%
import pandas as pd
import os
import glob
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns

# %%
city_files = glob.glob("*_data.csv")

all_cities_data = []

for file_name in city_files:
    city_df = pd.read_csv(file_name)
    all_cities_data.append(city_df)
    print(f"Loaded: {file_name}")

combined_data = pd.concat(all_cities_data, ignore_index=True)

combined_data.to_csv("all_cities_combined.csv", index=False)

print(f"SUCCESS: Combined {len(city_files)} city files into one file with {len(combined_data)} total rows")
print("The combined file is saved as: all_cities_combined.csv")
# Out:
# Loaded: Kochi_data.csv
# Loaded: Bhopal_data.csv
# Loaded: Lucknow_data.csv
# Loaded: Kolkata_data.csv
# Loaded: Guwahati_data.csv
# Loaded: Amaravati_data.csv
# Loaded: Aizawl_data.csv
# Loaded: Thiruvananthapuram_data.csv
# Loaded: Jaipur_data.csv
# Loaded: Ernakulam_data.csv
# Loaded: Bengaluru_data.csv
# Loaded: Mumbai_data.csv
# Loaded: Hyderabad_data.csv
# Loaded: Patna_data.csv
# Loaded: Talcher_data.csv
# Loaded: Shillong_data.csv
# Loaded: Coimbatore_data.csv
# Loaded: Visakhapatnam_data.csv
# Loaded: Chennai_data.csv
# Loaded: Gurugram_data.csv
# Loaded: Brajrajnagar_data.csv
# Loaded: Amritsar_data.csv
# Loaded: Jorapokhar_data.csv
# Loaded: Delhi_data.csv
# Loaded: Chandigarh_data.csv
# Loaded: Ahmedabad_data.csv
# SUCCESS: Combined 26 city files into one file with 29531 total rows
# The combined file is saved as: all_cities_combined.csv

# %%
df= pd.read_csv('all_cities_combined.csv')
df
# Out:
#             City        Date  PM2.5    PM10      NO    NO2     NOx    NH3  \
# 0          Kochi  22/01/2020  46.54  113.87   21.86  84.84   99.99  27.89
# 1          Kochi  23/01/2020  62.48  110.34   22.08  55.67   73.57  25.35
# 2          Kochi  24/01/2020  62.87  114.86   37.44  60.49   97.80  25.60
# 3          Kochi  25/01/2020  61.76  113.70   92.78  67.73  160.51  22.11
# 4          Kochi  26/01/2020  66.76  113.24  106.79  58.69  165.49  20.70
# ...          ...         ...    ...     ...     ...    ...     ...    ...
# 29526  Ahmedabad  27/06/2020  62.12  118.67    9.18  56.35   19.86    NaN
# 29527  Ahmedabad  28/06/2020  31.57     NaN    6.37  23.99   16.40    NaN
# 29528  Ahmedabad  29/06/2020  29.75  127.98    9.06  25.15   18.92    NaN
# 29529  Ahmedabad  30/06/2020  40.02  121.10    7.09  58.92   33.41    NaN
# 29530  Ahmedabad  01/07/2020  37.63     NaN    4.42  35.04   20.17    NaN
#
#          CO    SO2     O3  Benzene  Toluene  Xylene    AQI    AQI_Bucket
# 0      1.25   7.01  19.69      NaN     0.00     NaN    NaN           NaN
# 1      1.33   6.48   9.54      NaN     0.00     NaN  110.0      Moderate
# 2      1.44   6.91   9.06      NaN     0.00     NaN  111.0      Moderate
# 3      1.34   6.68  11.29      NaN     0.00     NaN  144.0      Moderate
# 4      1.36   6.75  11.43      NaN     0.05     NaN  197.0      Moderate
# ...     ...    ...    ...      ...      ...     ...    ...           ...
# 29526  0.49  12.44  68.05     1.32    37.76    1.62   92.0  Satisfactory
# 29527  0.52  11.01  26.34     1.37    49.58    1.34   82.0  Satisfactory
# 29528  0.67  12.10  34.99     1.39    60.21    0.79   74.0  Satisfactory
# 29529  0.73  16.39  41.64     1.21    44.10    1.35   98.0  Satisfactory
# 29530  0.28  14.40   9.69     1.73    47.05    1.87  119.0      Moderate
#
# [29531 rows x 16 columns]

# %%
df.head()
# Out:
#     City        Date  PM2.5    PM10      NO    NO2     NOx    NH3    CO   SO2  \
# 0  Kochi  22/01/2020  46.54  113.87   21.86  84.84   99.99  27.89  1.25  7.01
# 1  Kochi  23/01/2020  62.48  110.34   22.08  55.67   73.57  25.35  1.33  6.48
# 2  Kochi  24/01/2020  62.87  114.86   37.44  60.49   97.80  25.60  1.44  6.91
# 3  Kochi  25/01/2020  61.76  113.70   92.78  67.73  160.51  22.11  1.34  6.68
# 4  Kochi  26/01/2020  66.76  113.24  106.79  58.69  165.49  20.70  1.36  6.75
#
#       O3  Benzene  Toluene  Xylene    AQI AQI_Bucket
# 0  19.69      NaN     0.00     NaN    NaN        NaN
# 1   9.54      NaN     0.00     NaN  110.0   Moderate
# 2   9.06      NaN     0.00     NaN  111.0   Moderate
# 3  11.29      NaN     0.00     NaN  144.0   Moderate
# 4  11.43      NaN     0.05     NaN  197.0   Moderate

# %%
df.tail()
# Out:
#             City        Date  PM2.5    PM10    NO    NO2    NOx  NH3    CO  \
# 29526  Ahmedabad  27/06/2020  62.12  118.67  9.18  56.35  19.86  NaN  0.49
# 29527  Ahmedabad  28/06/2020  31.57     NaN  6.37  23.99  16.40  NaN  0.52
# 29528  Ahmedabad  29/06/2020  29.75  127.98  9.06  25.15  18.92  NaN  0.67
# 29529  Ahmedabad  30/06/2020  40.02  121.10  7.09  58.92  33.41  NaN  0.73
# 29530  Ahmedabad  01/07/2020  37.63     NaN  4.42  35.04  20.17  NaN  0.28
#
#          SO2     O3  Benzene  Toluene  Xylene    AQI    AQI_Bucket
# 29526  12.44  68.05     1.32    37.76    1.62   92.0  Satisfactory
# 29527  11.01  26.34     1.37    49.58    1.34   82.0  Satisfactory
# 29528  12.10  34.99     1.39    60.21    0.79   74.0  Satisfactory
# 29529  16.39  41.64     1.21    44.10    1.35   98.0  Satisfactory
# 29530  14.40   9.69     1.73    47.05    1.87  119.0      Moderate

# %%
df.shape
print(f'No of Rows: {df.shape[0]}, No of Columns: {df.shape[1]}')
# Out:
# No of Rows: 29531, No of Columns: 16

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %%
df.columns
# Out:
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %%
cities = df['City'].value_counts()
print(f'Total number of cities in the dataset : {len(cities)}')
cities
# Out:
# Total number of cities in the dataset : 26
# City
# Lucknow               2009
# Bengaluru             2009
# Chennai               2009
# Delhi                 2009
# Mumbai                2009
# Ahmedabad             2009
# Hyderabad             2006
# Patna                 1858
# Gurugram              1679
# Visakhapatnam         1462
# Amritsar              1221
# Jorapokhar            1169
# Jaipur                1114
# Thiruvananthapuram    1112
# Amaravati              951
# Brajrajnagar           938
# Talcher                925
# Kolkata                814
# Guwahati               502
# Coimbatore             386
# Shillong               310
# Chandigarh             304
# Bhopal                 289
# Kochi                  162
# Ernakulam              162
# Aizawl                 113
# Name: count, dtype: int64

# %%
df['City'].unique()
# Out:
# array(['Kochi', 'Bhopal', 'Lucknow', 'Kolkata', 'Guwahati', 'Amaravati',
#        'Aizawl', 'Thiruvananthapuram', 'Jaipur', 'Ernakulam', 'Bengaluru',
#        'Mumbai', 'Hyderabad', 'Patna', 'Talcher', 'Shillong',
#        'Coimbatore', 'Visakhapatnam', 'Chennai', 'Gurugram',
#        'Brajrajnagar', 'Amritsar', 'Jorapokhar', 'Delhi', 'Chandigarh',
#        'Ahmedabad'], dtype=object)

# %%
print(f"There are '{df.duplicated().sum()}' duplicates in the dataset")
# Out:
# There are '0' duplicates in the dataset

# %%
def missing_values_table(df):
    # Total missing values
    mis_val = df.isnull().sum()

    # Percentage of missing values
    mis_val_percent = 100 * mis_val / len(df)

    mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)

    mis_val_table = mis_val_table.rename(columns={0: 'Missing Values', 1: '% of Total Values'})

    # Sort the table by percentage of missing descending
    mis_val_table = mis_val_table.sort_values('% of Total Values', ascending=False)

    return mis_val_table

missing_values = missing_values_table(df)
display(missing_values.style.background_gradient(cmap='Greens'))
# Out:
# <style type="text/css">
# #T_e2ed2_row0_col0, #T_e2ed2_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_e2ed2_row1_col0, #T_e2ed2_row1_col1 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
# }
# #T_e2ed2_row2_col0, #T_e2ed2_row2_col1 {
#   background-color: #56b567;
#   color: #f1f1f1;
# }
# #T_e2ed2_row3_col0, #T_e2ed2_row3_col1 {
#   background-color: #88ce87;
#   color: #000000;
# }
# #T_e2ed2_row4_col0, #T_e2ed2_row4_col1 {
#   background-color: #b5e1ae;
#   color: #000000;
# }
# #T_e2ed2_row5_col0, #T_e2ed2_row5_col1, #T_e2ed2_row6_col0, #T_e2ed2_row6_col1 {
#   background-color: #c4e8bd;
#   color: #000000;
# }
# #T_e2ed2_row7_col0, #T_e2ed2_row7_col1 {
#   background-color: #c6e8bf;
#   color: #000000;
# }
# #T_e2ed2_row8_col0, #T_e2ed2_row8_col1 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_e2ed2_row9_col0, #T_e2ed2_row9_col1 {
#   background-color: #ceecc8;
#   color: #000000;
# }
# #T_e2ed2_row10_col0, #T_e2ed2_row10_col1 {
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_e2ed2_row11_col0, #T_e2ed2_row11_col1, #T_e2ed2_row12_col0, #T_e2ed2_row12_col1 {
#   background-color: #d4eece;
#   color: #000000;
# }
# #T_e2ed2_row13_col0, #T_e2ed2_row13_col1 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_e2ed2_row14_col0, #T_e2ed2_row14_col1, #T_e2ed2_row15_col0, #T_e2ed2_row15_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_e2ed2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2ed2_level0_col0" class="col_heading level0 col0" >Missing Values</th>
#       <th id="T_e2ed2_level0_col1" class="col_heading level0 col1" >% of Total Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2ed2_level0_row0" class="row_heading level0 row0" >Xylene</th>
#       <td id="T_e2ed2_row0_col0" class="data row0 col0" >18109</td>
#       <td id="T_e2ed2_row0_col1" class="data row0 col1" >61.322001</td>
#     </tr>
#     <tr>
#       <th id="T_e2ed2_level0_row1" class="row_heading level0 row1" >PM10</th>
#       <td id="T_e2ed2_row1_col0" class="data row1 col0" >11140</td>
#       <td id="T_e2ed2_row1_col1" class="data row1 col1" >37.723071</td>
#     </tr>
#     <tr>
#       <th id="T_e2ed2_level0_row2" class="row_heading level0 row2" >NH3</th>
#       <td id="T_e2ed2_row2_col0" class="data row2 col0" >10328</td>
#       <td id="T_e2ed2_row2_col1" class="data row2 col1" >34.973418</td>
#     </tr>
#     <tr>
#       <th id="T_e2ed2_level0_row3" class="row_heading level0 row3" >Toluene</th>
#       <td id="T_e2ed2_row3_col0" class="data row3 col0" >8041</td>
#       <td id="T_e2ed2_row3_col1" class="data row3 col1" >27.229014</td>
#     </tr>
#     <tr>
#       <th id="T_e2ed2_level0_row4" class="row_heading level0 row4" >Benzene</th>
#       <td id="T_e2ed2_row4_col0" class="data row4 col0" >5623</td>
#       <td id="T_e2ed2_row4_col1" class="data row4 col1" >19.041008</td>
#     </tr>
#     <tr>
#       <th id="T_e2ed2_level0_row5" class="row_heading level0 row5" >AQI</th>
#       <td id="T_e2ed2_row5_col0" class="data row5 col0" >4681</td>
#       <td id="T_e2ed2_row5_col1" class="data row5 col1" >15.851139</td>
#     </tr>
#     <tr>
#       <th id="T_e2ed2_level0_row6" class="row_heading level0 row6" >AQI_Bucket</th>
#       <td id="T_e2ed2_row6_col0" class="data row6 col0" >4681</td>
#       <td id="T_e2ed2_row6_col1" class="data row6 col1" >15.851139</td>
#     </tr>
#     <tr>
#       <th id="T_e2ed2_level0_row7" class="row_heading level0 row7" >PM2.5</th>
#       <td id="T_e2ed2_row7_col0" class="data row7 col0" >4598</td>
#       <td id="T_e2ed2_row7_col1" class="data row7 col1" >15.570079</td>
#     </tr>
#     <tr>
#       <th id="T_e2ed2_level0_row8" class="row_heading level0 row8" >NOx</th>
#       <td id="T_e2ed2_row8_col0" class="data row8 col0" >4185</td>
#       <td id="T_e2ed2_row8_col1" class="data row8 col1" >14.171549</td>
#     </tr>
#     <tr>
#       <th id="T_e2ed2_level0_row9" class="row_heading level0 row9" >O3</th>
#       <td id="T_e2ed2_row9_col0" class="data row9 col0" >4022</td>
#       <td id="T_e2ed2_row9_col1" class="data row9 col1" >13.619586</td>
#     </tr>
#     <tr>
#       <th id="T_e2ed2_level0_row10" class="row_heading level0 row10" >SO2</th>
#       <td id="T_e2ed2_row10_col0" class="data row10 col0" >3854</td>
#       <td id="T_e2ed2_row10_col1" class="data row10 col1" >13.050692</td>
#     </tr>
#     <tr>
#       <th id="T_e2ed2_level0_row11" class="row_heading level0 row11" >NO2</th>
#       <td id="T_e2ed2_row11_col0" class="data row11 col0" >3585</td>
#       <td id="T_e2ed2_row11_col1" class="data row11 col1" >12.139785</td>
#     </tr>
#     <tr>
#       <th id="T_e2ed2_level0_row12" class="row_heading level0 row12" >NO</th>
#       <td id="T_e2ed2_row12_col0" class="data row12 col0" >3582</td>
#       <td id="T_e2ed2_row12_col1" class="data row12 col1" >12.129626</td>
#     </tr>
#     <tr>
#       <th id="T_e2ed2_level0_row13" class="row_heading level0 row13" >CO</th>
#       <td id="T_e2ed2_row13_col0" class="data row13 col0" >2059</td>
#       <td id="T_e2ed2_row13_col1" class="data row13 col1" >6.972334</td>
#     </tr>
#     <tr>
#       <th id="T_e2ed2_level0_row14" class="row_heading level0 row14" >Date</th>
#       <td id="T_e2ed2_row14_col0" class="data row14 col0" >0</td>
#       <td id="T_e2ed2_row14_col1" class="data row14 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e2ed2_level0_row15" class="row_heading level0 row15" >City</th>
#       <td id="T_e2ed2_row15_col0" class="data row15 col0" >0</td>
#       <td id="T_e2ed2_row15_col1" class="data row15 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Visualize the missing values using a heatmap
plt.figure(figsize=(15, 8))
sns.heatmap(df.isnull(), cbar=False, cmap='plasma')
plt.title('Missing Values Heatmap')
plt.xlabel('Columns')
plt.ylabel('Rows')
plt.show()

# %%
missing_values_per_cities = df.groupby('City').apply(lambda x: x.isnull().sum())
missing_values_per_cities
# Out:
# /tmp/ipython-input-3208573697.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   missing_values_per_cities = df.groupby('City').apply(lambda x: x.isnull().sum())
#                     City  Date  PM2.5  PM10    NO   NO2   NOx   NH3   CO  \
# City
# Ahmedabad              0     0    628  1602   609   608   594  2009  609
# Aizawl                 0     0      2     1     0     0     0     0    0
# Amaravati              0     0     59    55    55    55    55    55   97
# Amritsar               0     0    128    63    93    44   289    42   76
# Bengaluru              0     0    146   360     6     6     4   203   11
# Bhopal                 0     0      9     9     9     9     9     9    9
# Brajrajnagar           0     0    185   173   243   234   175   226  150
# Chandigarh             0     0     15     0     4     4     4    10    0
# Chennai                0     0    117  1707    36    36    36   462   25
# Coimbatore             0     0      8     7    55    11     4   123    3
# Delhi                  0     0      2    77     2     2     0     9    0
# Ernakulam              0     0      4     4     4    55     4     4    4
# Gurugram               0     0    154   939   138   136   452  1560  109
# Guwahati               0     0      1     0     1     1     1     1    1
# Hyderabad              0     0    115   355    28    28     7   360    5
# Jaipur                 0     0     12    14    16    14   112    15    7
# Jorapokhar             0     0    790   275   270   270  1169   368  513
# Kochi                  0     0      0     0     2     6     0    16    0
# Kolkata                0     0     55    55    26    25     1     0    0
# Lucknow                0     0    102  2009    24    24   324  1004   28
# Mumbai                 0     0   1225  1246  1242  1253   499  1614   25
# Patna                  0     0    321  1667   203   204   203  1667  151
# Shillong               0     0     64    69    59    59    33    59   33
# Talcher                0     0    184   179   200   222   156   186  148
# Thiruvananthapuram     0     0     42    38    31    31    16   113   16
# Visakhapatnam          0     0    230   236   226   248    38   213   39
#
#                      SO2    O3  Benzene  Toluene  Xylene   AQI  AQI_Bucket
# City
# Ahmedabad            640   685      483      483     484   675         675
# Aizawl                 0     9       15       15     113     2           2
# Amaravati             65    55       75       75     269   110         110
# Amritsar             168   115      195      212     213    95          95
# Bengaluru              6   144      266       93    2009    99          99
# Bhopal                 9     9      289      289     289    11          11
# Brajrajnagar         193   203      173      938     938   225         225
# Chandigarh             0     0        0        0       0     5           5
# Chennai               36    49      285      253    2009   125         125
# Coimbatore             3     3        3        3     386    42          42
# Delhi                110    84        0        0     781    10          10
# Ernakulam              4   162        4        4       4     9           9
# Gurugram             175   116      442      610    1560   226         226
# Guwahati               1     1        7      502     502     7           7
# Hyderabad             26    26      127      127     127   126         126
# Jaipur                12    15       22       23    1114    20          20
# Jorapokhar           351   294     1169     1169    1169   398         398
# Kochi                  0     0      162        0     162     4           4
# Kolkata               62    50        1        1     420    60          60
# Lucknow               64    27       99      136    2009   116         116
# Mumbai              1220  1212      210      993     994  1234        1234
# Patna                205   278      172      173     172   399         399
# Shillong              54    56       33       34     310   105         105
# Talcher              192   169      241      758     925   227         227
# Thiruvananthapuram    31    31     1112     1112    1112    60          60
# Visakhapatnam        227   229       38       38      38   291         291

# %%
print("Total missing values per City:")
print(df.groupby('City').apply(lambda x: x.isnull().sum().sum()))
# Out:
# Total missing values per City:
# City
# Ahmedabad             10784
# Aizawl                  159
# Amaravati              1190
# Amritsar               1828
# Bengaluru              3452
# Bhopal                  970
# Brajrajnagar           4281
# Chandigarh               47
# Chennai                5301
# Coimbatore              693
# Delhi                  1087
# Ernakulam               275
# Gurugram               6843
# Guwahati               1033
# Hyderabad              1583
# Jaipur                 1416
# Jorapokhar             8603
# Kochi                   356
# Kolkata                 816
# Lucknow                6082
# Mumbai                14201
# Patna                  6214
# Shillong               1073
# Talcher                4014
# Thiruvananthapuram     3805
# Visakhapatnam          2382
# dtype: int64
# /tmp/ipython-input-2279394426.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   print(df.groupby('City').apply(lambda x: x.isnull().sum().sum()))

# %% [markdown]
# Data Cleaning

# %%
df.isna().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %%
df[['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene','AQI','AQI_Bucket']] = df[['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene','AQI','AQI_Bucket']].ffill()

# %%
df.isna().sum()
# Out:
# City             0
# Date             0
# PM2.5            0
# PM10             0
# NO               0
# NO2              0
# NOx              0
# NH3              0
# CO               0
# SO2              0
# O3               0
# Benzene        451
# Toluene          0
# Xylene        2876
# AQI              1
# AQI_Bucket       1
# dtype: int64

# %%
df[['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene','AQI','AQI_Bucket']] = df[['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene','AQI','AQI_Bucket']].bfill()

# %%
df.isna().sum()
# Out:
# City          0
# Date          0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# CO            0
# SO2           0
# O3            0
# Benzene       0
# Toluene       0
# Xylene        0
# AQI           0
# AQI_Bucket    0
# dtype: int64

# %%
print("Total missing values per City:")
print(df.groupby('City').apply(lambda x: x.isnull().sum().sum()))
# Out:
# Total missing values per City:
# City
# Ahmedabad             0
# Aizawl                0
# Amaravati             0
# Amritsar              0
# Bengaluru             0
# Bhopal                0
# Brajrajnagar          0
# Chandigarh            0
# Chennai               0
# Coimbatore            0
# Delhi                 0
# Ernakulam             0
# Gurugram              0
# Guwahati              0
# Hyderabad             0
# Jaipur                0
# Jorapokhar            0
# Kochi                 0
# Kolkata               0
# Lucknow               0
# Mumbai                0
# Patna                 0
# Shillong              0
# Talcher               0
# Thiruvananthapuram    0
# Visakhapatnam         0
# dtype: int64
# /tmp/ipython-input-2279394426.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   print(df.groupby('City').apply(lambda x: x.isnull().sum().sum()))

# %%
# Visualize the missing values using a heatmap after cleaning
plt.figure(figsize=(15, 8))
sns.heatmap(df.isnull(), cbar=False, cmap='plasma')
plt.title('Missing Values Heatmap')
plt.xlabel('Columns')
plt.ylabel('Rows')
plt.show()

# %%
df.describe().T
# Out:
#            count                           mean                  min  \
# Date       29531  2018-05-14 05:40:15.807118080  2015-01-01 00:00:00
# PM2.5    29531.0                      65.219156                 0.04
# PM10     29531.0                      95.010579                 0.01
# NO       29531.0                      17.104544                 0.02
# NO2      29531.0                      26.879051                 0.01
# NOx      29531.0                      33.286562                  0.0
# NH3      29531.0                      24.037246                 0.01
# CO       29531.0                       2.292705                  0.0
# SO2      29531.0                      15.672823                 0.01
# O3       29531.0                      33.498672                 0.01
# Benzene  29531.0                        3.84011                  0.0
# Toluene  29531.0                       7.924786                  0.0
# Xylene   29531.0                       2.281277                  0.0
# AQI      29531.0                     161.606786                 13.0
# month    29531.0                       6.267143                  1.0
#
#                          25%                  50%                  75%  \
# Date     2017-04-16 00:00:00  2018-08-05 00:00:00  2019-09-03 00:00:00
# PM2.5                 25.885                46.56                78.62
# PM10                   39.94                69.49              118.495
# NO                      5.22                 9.33                18.67
# NO2                    11.65                19.74                35.03
# NOx                    13.12                24.18                38.85
# NH3                     8.05                15.65                33.52
# CO                       0.5                 0.91                 1.49
# SO2                     5.74                 8.95                15.84
# O3                     17.24                29.71                44.62
# Benzene                 0.12                  1.3                 3.31
# Toluene                 0.57                 2.74                 9.25
# Xylene                   0.0                 0.45                 3.14
# AQI                     76.0                113.0                205.0
# month                    3.0                  6.0                  9.0
#
#                          max         std
# Date     2020-07-01 00:00:00         NaN
# PM2.5                 949.99   64.612432
# PM10                  1000.0   83.390054
# NO                    390.68   23.342599
# NO2                   362.21   23.691243
# NOx                   467.63   33.654836
# NH3                   352.89   25.964758
# CO                    175.81    6.824273
# SO2                   193.86   20.573356
# O3                    257.73   21.960658
# Benzene               455.03   16.180381
# Toluene               454.85   17.837545
# Xylene                170.37     5.19955
# AQI                   2049.0  139.381343
# month                   12.0    3.431974

# %% [markdown]
# EDA

# %%
pollutants = ['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene','AQI','AQI_Bucket']
axes = df[pollutants].plot(marker='.', alpha=0.3, linestyle='None', figsize=(16, 20), subplots=True)
for ax in axes:
    ax.set_xlabel('Years')
    ax.set_ylabel('ug / m3')        # plots shows variations of different parameters

# %%
city_stats = df.groupby('City')[['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene']].mean().reset_index()

import plotly.express as px

# Melt the DataFrame to create a 'Pollutant' column
city_stats_melted = pd.melt(city_stats,
                               id_vars=['City'],
                               value_vars=['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene'],
                               var_name='Pollutant',
                               value_name='Average Concentration')

# Create the stacked bar chart
fig_station = px.bar(city_stats_melted,
                     y='City',  # Move City to the y-axis
                     x='Average Concentration',  # Move Average Concentration to the x-axis
                     color='Pollutant',  # Use 'Pollutant' for color differentiation
                     title='Average Pollution Levels by Station (Vertical Stacked)',
                     labels={'City': 'Cities', 'Average Concentration': 'Average Concentration'},
                     barmode='stack')  # Keep the stacking behavior
fig_station.update_layout(
    height=800,  # Adjust height for better visibility
)

fig_station.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="83cc7951-4029-4b80-a47e-14eee76afe4b" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("83cc7951-4029-4b80-a47e-14eee76afe4b")) {                    Plotly.newPlot(                        "83cc7951-4029-4b80-a47e-14eee76afe4b",                        [{"alignmentgroup":"True","hovertemplate":"Pollutant=PM2.5\u003cbr\u003eAverage Concentration=%{x}\u003cbr\u003eCities=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PM2.5","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"PM2.5","offsetgroup":"PM2.5","orientation":"h","showlegend":true,"textposition":"auto","x":[92.43807366849178,16.850530973451328,36.280630914826496,53.36689598689599,34.187685415629666,48.98923875432526,62.87934968017058,40.71470394736842,48.93666002986561,29.146968911917096,117.10121453459432,24.82611111111111,117.96518165574747,63.8604780876494,44.809900299102694,54.17942549371634,57.71088109495295,31.42851851851852,61.143624078624086,105.185550024888,24.525460428073668,115.88369214208826,28.144709677419357,56.730313513513515,27.641034172661872,44.554179206566346],"xaxis":"x","y":["Ahmedabad","Aizawl","Amaravati","Amritsar","Bengaluru","Bhopal","Brajrajnagar","Chandigarh","Chennai","Coimbatore","Delhi","Ernakulam","Gurugram","Guwahati","Hyderabad","Jaipur","Jorapokhar","Kochi","Kolkata","Lucknow","Mumbai","Patna","Shillong","Talcher","Thiruvananthapuram","Visakhapatnam"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Pollutant=PM10\u003cbr\u003eAverage Concentration=%{x}\u003cbr\u003eCities=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PM10","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"PM10","offsetgroup":"PM10","orientation":"h","showlegend":true,"textposition":"auto","x":[81.24589845694375,23.200973451327435,73.64248159831756,117.48280098280098,72.15686411149827,116.5952249134948,121.50214285714286,85.65654605263158,67.83950721752116,37.821528497409325,233.9497162767546,48.18030864197531,106.24880285884454,116.60490039840639,80.6682552342971,122.78559245960503,149.1447390932421,67.33543209876544,109.96271498771497,30.0,55.96032852165256,72.6934122712594,38.89535483870968,151.7692108108108,52.19079136690648,102.95991108071136],"xaxis":"x","y":["Ahmedabad","Aizawl","Amaravati","Amritsar","Bengaluru","Bhopal","Brajrajnagar","Chandigarh","Chennai","Coimbatore","Delhi","Ernakulam","Gurugram","Guwahati","Hyderabad","Jaipur","Jorapokhar","Kochi","Kolkata","Lucknow","Mumbai","Patna","Shillong","Talcher","Thiruvananthapuram","Visakhapatnam"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Pollutant=NO\u003cbr\u003eAverage Concentration=%{x}\u003cbr\u003eCities=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NO","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"NO","offsetgroup":"NO","orientation":"h","showlegend":true,"textposition":"auto","x":[17.946490791438528,9.408053097345132,5.1535436382755,18.703890253890254,9.394051767048284,6.843598615916955,24.216194029850747,10.433519736842106,9.092254853160776,6.460336787564767,38.971533101045296,23.43179012345679,16.952703990470518,20.015896414342627,7.877432701894317,14.552414721723519,10.41098374679213,70.90024691358025,26.706179361179363,15.129123942259831,18.084046789447484,29.574424111948332,0.9369032258064516,33.13916756756757,3.3968794964028777,12.554829001367988],"xaxis":"x","y":["Ahmedabad","Aizawl","Amaravati","Amritsar","Bengaluru","Bhopal","Brajrajnagar","Chandigarh","Chennai","Coimbatore","Delhi","Ernakulam","Gurugram","Guwahati","Hyderabad","Jaipur","Jorapokhar","Kochi","Kolkata","Lucknow","Mumbai","Patna","Shillong","Talcher","Thiruvananthapuram","Visakhapatnam"],"yaxis":"y","type":"b ...

# %%
Cities = df['City'].unique()
pollutants = ['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene']

for City in Cities:
    city_data = df[df['City'] == City]
    plt.figure(figsize=(16, 6))
    for pollutant in pollutants:
        plt.bar(pollutant, city_data[pollutant].mean(), label=pollutant)
    plt.title(f'Average Pollutant Levels at Station {City}')
    plt.xlabel('Pollutant')
    plt.ylabel('Average Concentration')
    plt.legend()
    plt.show()

# %%
def max_polluted_cities(selected_pollutants):
    x1 = df[[selected_pollutants,'City']].groupby(["City"]).mean().sort_values(by=selected_pollutants,ascending=False).reset_index()
    x1[selected_pollutants] = round(x1[selected_pollutants],2)
    return x1[:6].style.background_gradient(cmap='OrRd')

# %%
from IPython.display import display_html

def display_side_by_side(*args):
    # Convert each DataFrame's Styler object to HTML and join them together
    html_str = ''
    for df in args:
        html_str += df._repr_html_()  # Use _repr_html_ to get the HTML representation
    display_html(html_str.replace('table', 'table style="display:inline;margin-right:20px;"'), raw=True)

pm2_5 = max_polluted_cities('PM2.5')
pm10 = max_polluted_cities('PM10')
no = max_polluted_cities('NO')
no2 = max_polluted_cities('NO2')
nox = max_polluted_cities('NOx')
NH3 = max_polluted_cities('NH3')
air_qua = max_polluted_cities('AQI')

# Display the DataFrames side by side
display_side_by_side(pm2_5, pm10, no, no2, nox, NH3, air_qua)
# Out:
# <style type="text/css">
# #T_13aa8_row0_col1 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_13aa8_row1_col1 {
#   background-color: #860000;
#   color: #f1f1f1;
# }
# #T_13aa8_row2_col1 {
#   background-color: #8e0000;
#   color: #f1f1f1;
# }
# #T_13aa8_row3_col1 {
#   background-color: #d32a1b;
#   color: #f1f1f1;
# }
# #T_13aa8_row4_col1 {
#   background-color: #f98455;
#   color: #f1f1f1;
# }
# #T_13aa8_row5_col1 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# </style>
# <table style="display:inline;margin-right:20px;" id="T_13aa8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13aa8_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_13aa8_level0_col1" class="col_heading level0 col1" >PM2.5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13aa8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_13aa8_row0_col0" class="data row0 col0" >Gurugram</td>
#       <td id="T_13aa8_row0_col1" class="data row0 col1" >117.970000</td>
#     </tr>
#     <tr>
#       <th id="T_13aa8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_13aa8_row1_col0" class="data row1 col0" >Delhi</td>
#       <td id="T_13aa8_row1_col1" class="data row1 col1" >117.100000</td>
#     </tr>
#     <tr>
#       <th id="T_13aa8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_13aa8_row2_col0" class="data row2 col0" >Patna</td>
#       <td id="T_13aa8_row2_col1" class="data row2 col1" >115.880000</td>
#     </tr>
#     <tr>
#       <th id="T_13aa8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_13aa8_row3_col0" class="data row3 col0" >Lucknow</td>
#       <td id="T_13aa8_row3_col1" class="data row3 col1" >105.190000</td>
#     </tr>
#     <tr>
#       <th id="T_13aa8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_13aa8_row4_col0" class="data row4 col0" >Ahmedabad</td>
#       <td id="T_13aa8_row4_col1" class="data row4 col1" >92.440000</td>
#     </tr>
#     <tr>
#       <th id="T_13aa8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_13aa8_row5_col0" class="data row5 col0" >Guwahati</td>
#       <td id="T_13aa8_row5_col1" class="data row5 col1" >63.860000</td>
#     </tr>
#   </tbody>
# </table style="display:inline;margin-right:20px;">
# <style type="text/css">
# #T_ad697_row0_col1 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_ad697_row1_col1 {
#   background-color: #fdcb95;
#   color: #000000;
# }
# #T_ad697_row2_col1 {
#   background-color: #fdd09a;
#   color: #000000;
# }
# #T_ad697_row3_col1 {
#   background-color: #fff2e0;
#   color: #000000;
# }
# #T_ad697_row4_col1 {
#   background-color: #fff3e3;
#   color: #000000;
# }
# #T_ad697_row5_col1 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# </style>
# <table style="display:inline;margin-right:20px;" id="T_ad697">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad697_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_ad697_level0_col1" class="col_heading level0 col1" >PM10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad697_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ad697_row0_col0" class="data row0 col0" >Delhi</td>
#       <td id="T_ad697_row0_col1" class="data row0 col1" >233.950000</td>
#     </tr>
#     <tr>
#       <th id="T_ad697_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ad697_row1_col0" class="data row1 col0" >Talcher</td>
#       <td id="T_ad697_row1_col1" class="data row1 col1" >151.770000</td>
#     </tr>
#     <tr>
#       <th id="T_ad697_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ad697_row2_col0" class="data row2 col0" >Jorapokhar</td>
#       <td id="T_ad697_row2_col1" class="data row2 col1" >149.140000</td>
#     </tr>
#     <tr>
#       <th id="T_ad697_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ad697_row3_col0" class="data row3 col0" >Jaipur</td>
#       <td id="T_ad697_row3_col1" class="data row3 col1" >122.790000</td>
#     </tr>
#     <tr>
#       <th id="T_ad697_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ad697_row4_col0" class="data row4 col0" >Brajrajnagar</td>
#       <td id="T_ad697_row4_col1" class="data row4 col1" >121.500000</td>
#     </tr>
#     <tr>
#       <th id="T_ad697_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ad697_row5_col0" class="data row5 col0" >Amritsar</td>
#       <td id="T_ad697_row5_col1" class="data row5 col1" >117.480000</td>
#     </tr>
#   </tbody>
# </table style="display:inline;margin-right:20px;">
# <style type="text/css">
# #T_820ba_row0_col1 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_820ba_row1_col1 {
#   background-color: #fdc791;
#   color: #000000;
# }
# #T_820ba_row2_col1 {
#   background-color: #fddeb3;
#   color: #000000;
# }
# #T_820ba_row3_col1 {
#   background-color: #fee9cb;
#   color: #000000;
# }
# #T_820ba_row4_col1 {
#   background-color: #fff1dd;
#   color: #000000;
# }
# #T_820ba_row5_col1 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# </style>
# <table style="display:inline;margin-right:20px;" id="T_820ba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_820ba_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_820ba_level0_col1" class="col_heading level0 col1" >NO</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_820ba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_820ba_row0_col0" class="data row0 col0" >Kochi</td>
#       <td id="T_820ba_row0_col1" class="data row0 col1" >70.900000</td>
#     </tr>
#     <tr>
#       <th id="T_820ba_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_820ba_row1_col0" class="data row1 col0" >Delhi</td>
#       <td id="T_820ba_row1_col1" class="data row1 col1" >38.970000</td>
#     </tr>
#     <tr>
#       <th id="T_820ba_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_820ba_row2_col0" class="data row2 col0" >Talcher</td>
#       <td id="T_820ba_row2_col1" class="data row2 col1" >33.140000</td>
#     </tr>
#     <tr>
#       <th id="T_820ba_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_820ba_row3_col0" class="data row3 col0" >Patna</td>
#       <td id="T_820ba_row3_col1" class="data row3 col1" >29.570000</td>
#     </tr>
#     <tr>
#       <th id="T_820ba_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_820ba_row4_col0" class="data row4 col0" >Kolkata</td>
#       <td id="T_820ba_row4_col1" class="data row4 col1" >26.710000</td>
#     </tr>
#     <tr>
#       <th id="T_820ba_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_820ba_row5_col0" class="data row5 col0" >Brajrajnagar</td>
#       <td id="T_820ba_row5_col1" class="data row5 col1" >24.220000</td>
#     </tr>
#   </tbody>
# </table style="display:inline;margin-right:20px;">
# <style type="text/css">
# #T_74991_row0_col1 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_74991_row1_col1 {
#   background-color: #c51810;
#   color: #f1f1f1;
# }
# #T_74991_row2_col1 {
#   background-color: #fdb57e;
#   color: #000000;
# }
# #T_74991_row3_col1 {
#   background-color: #fee2bc;
#   color: #000000;
# }
# #T_74991_row4_col1 {
#   background-color: #fff0dc;
#   color: #000000;
# }
# #T_74991_row5_col1 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# </style>
# <table style="display:inline;margin-right:20px;" id="T_74991">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74991_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_74991_level0_col1" class="col_heading level0 col1" >NO2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74991_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_74991_row0_col0" class="data row0 col0" >Delhi</td>
#       <td id="T_74991_row0_col1" class="data row0 col1" >50.770000</td>
#     </tr>
#     <tr>
#       <th id="T_74991_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_74991_row1_col0" class="data row1 col0" >Ahmedabad</td>
#       <td id="T_74991_row1_col1" class="data row1 col1" >47.430000</td>
#     </tr>
#     <tr>
#       <t

# %%
pollutant_columns = ['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene']

# Step 1: Group by station and calculate mean pollutant concentrations
mean_pollutant_by_station = df.groupby('City')[pollutant_columns].mean()

# Step 2: Find the top 5 stations for each pollutant
top_stations = {}
for pollutant in pollutant_columns:
    top_stations[pollutant] = mean_pollutant_by_station[pollutant].sort_values(ascending=False).head(5)

# Step 3: Plotting
fig, axes = plt.subplots(len(pollutant_columns), 1, figsize=(10, 20))

for i, pollutant in enumerate(pollutant_columns):
    axes[i].barh(top_stations[pollutant].index, top_stations[pollutant].values, color='red')
    axes[i].set_title(f'Top 5 Cities by {pollutant}')
    axes[i].set_xlabel(f'{pollutant}')
    axes[i].invert_yaxis()  # Highest values on top

plt.tight_layout()
plt.show()

# %%
import plotly.express as px

# Calculate the A verage of each pollutant
pollutants = ['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene']
mean_pollutants = df[pollutants].mean()

# Create the bar chart
fig = px.bar(
    x=pollutants,
    y=mean_pollutants,
    title='Average of Each Pollutant',
    labels={'x': 'Pollutant', 'y': 'Average Concentration'}
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="106e28cf-0a58-4e03-917a-73e2525af033" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("106e28cf-0a58-4e03-917a-73e2525af033")) {                    Plotly.newPlot(                        "106e28cf-0a58-4e03-917a-73e2525af033",                        [{"alignmentgroup":"True","hovertemplate":"Pollutant=%{x}\u003cbr\u003eAverage Concentration=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["PM2.5","PM10","NO","NO2","NOx","NH3","CO","SO2","O3","Benzene","Toluene","Xylene"],"xaxis":"x","y":[65.21915647963158,95.01057871389389,17.104544377095255,26.879050827943516,33.28656191798449,24.037245606312013,2.292705292743219,15.672823135010667,33.49867156547357,3.8401097152145205,7.9247858182926425,2.2812773018184282],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}} ...

# %%
import matplotlib.pyplot as plt

pollutants = ['PM2.5','PM10','NO','NO2','NOx','NH3','SO2','O3','Toluene']
total_pollutant_concentration = df[pollutants].sum().sum()  # Calculates total concentration across all pollutants

# Calculate percentage for each pollutant
pollutant_percentages = [(df[pollutant].sum() / total_pollutant_concentration) * 100 for pollutant in pollutants]

# Create the pie chart
plt.figure(figsize=(16, 16))  # Adjust figure size if needed
plt.pie(pollutant_percentages, labels=pollutants, autopct='%1.1f%%', startangle=90)
plt.title('Percentage of Pollutants')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# List of key variables (pollutants)
key_variables = ['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene']

# Set the size of the entire figure
plt.figure(figsize=(16, 10))

# Create subplots for each key variable
for i, column in enumerate(key_variables, 1):
    plt.subplot(4, 3, i)  # 4 rows, 3 columns, position i
    sns.histplot(df[column], kde=True, bins=30)
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')

plt.tight_layout()

plt.show()

# %%
# Select numerical columns for visualization
numerical_columns = ['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene']

# Create subplots
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(15, 15))
axes = axes.flatten()

for i, column in enumerate(numerical_columns):
    ax = axes[i]
    df[column].hist(bins=50, ax=ax, color='teal', alpha=0.7)
    ax.set_title(column)
    ax.set_xlabel('Value')
    ax.set_ylabel('Frequency')

# Remove empty subplots
for j in range(len(numerical_columns), len(axes)):
    fig.delaxes(axes[j])
plt.suptitle("Distribution of Each Pollutant", fontsize=20)
plt.tight_layout()
plt.show()

# %%
# Define the pollutants to analyze
pollutants = ['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene']

# Create a figure and subplots
fig, axes = plt.subplots(4, 3, figsize=(15, 10))  # 2 rows, 3 columns

# Flatten the axes array for easier iteration
axes = axes.flatten()

# Create a box plot for each pollutant in a subplot
for i, pollutant in enumerate(pollutants):
    axes[i].boxplot(df[pollutant], vert=False, patch_artist=True, showfliers=False)
    axes[i].set_title(f'Box Plot of {pollutant}')
    axes[i].set_xlabel(pollutant)

# Adjust layout to prevent overlapping
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Select only numeric columns for correlation calculation
pollutants =df[['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene']]

# Calculate the correlation matrix
correlation_matrix = pollutants.corr()

plt.figure(figsize=(18, 10))  # Adjust figure size as needed
sns.heatmap(correlation_matrix, annot=True, cmap='RdBu', fmt=".2f")
plt.title('Correlation Matrix of Air Quality Data')
plt.show()

# %%
pollutants.corr()
# Out:
#             PM2.5      PM10        NO       NO2       NOx       NH3        CO  \
# PM2.5    1.000000  0.380695  0.360660  0.340838  0.253873  0.155554  0.107834
# PM10     0.380695  1.000000  0.381781  0.319149  0.295865  0.126762 -0.002172
# NO       0.360660  0.381781  1.000000  0.421468  0.595488  0.097973  0.196227
# NO2      0.340838  0.319149  0.421468  1.000000  0.471972  0.135368  0.353825
# NOx      0.253873  0.295865  0.595488  0.471972  1.000000  0.012226  0.181006
# NH3      0.155554  0.126762  0.097973  0.135368  0.012226  1.000000  0.087772
# CO       0.107834 -0.002172  0.196227  0.353825  0.181006  0.087772  1.000000
# SO2      0.134913  0.153409  0.133056  0.283497  0.132654 -0.012702  0.430675
# O3       0.181983  0.189841  0.043318  0.294553  0.038427  0.076628  0.054089
# Benzene -0.004314 -0.006226  0.003558  0.008306 -0.009990 -0.023667  0.057295
# Toluene  0.108489  0.092917  0.109077  0.270741  0.108611  0.041009  0.276809
# Xylene   0.062630  0.052615  0.052660  0.106959  0.027929 -0.096252  0.129012
#
#               SO2        O3   Benzene   Toluene    Xylene
# PM2.5    0.134913  0.181983 -0.004314  0.108489  0.062630
# PM10     0.153409  0.189841 -0.006226  0.092917  0.052615
# NO       0.133056  0.043318  0.003558  0.109077  0.052660
# NO2      0.283497  0.294553  0.008306  0.270741  0.106959
# NOx      0.132654  0.038427 -0.009990  0.108611  0.027929
# NH3     -0.012702  0.076628 -0.023667  0.041009 -0.096252
# CO       0.430675  0.054089  0.057295  0.276809  0.129012
# SO2      1.000000  0.142002 -0.003575  0.176984  0.223809
# O3       0.142002  1.000000  0.032454  0.148209  0.082568
# Benzene -0.003575  0.032454  1.000000  0.637318  0.057827
# Toluene  0.176984  0.148209  0.637318  1.000000  0.201328
# Xylene   0.223809  0.082568  0.057827  0.201328  1.000000

# %%
import numpy as np
# Select relevant columns for correlation analysis
corr_cols = ['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene']
corr_matrix = df[corr_cols].corr()

# Create text annotations for percentages
text_annotations = np.around(corr_matrix.values, decimals=2)
text_annotations = text_annotations.astype(str)

# Creating heatmap
fig = go.Figure(data=go.Heatmap(
                   z=corr_matrix.values,
                   x=corr_cols,
                   y=corr_cols,
                   colorscale='Inferno',
                   hoverongaps = False,
                   text=text_annotations,  # Add text annotations
                   texttemplate="%{text}"  # Format text as percentages
                   ))

fig.update_layout(title='Correlation Matrix of Weather Conditions and Pollutants')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="341a40b5-2ee9-4066-9c9d-e7021dbc47cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("341a40b5-2ee9-4066-9c9d-e7021dbc47cf")) {                    Plotly.newPlot(                        "341a40b5-2ee9-4066-9c9d-e7021dbc47cf",                        [{"colorscale":[[0.0,"#000004"],[0.1111111111111111,"#1b0c41"],[0.2222222222222222,"#4a0c6b"],[0.3333333333333333,"#781c6d"],[0.4444444444444444,"#a52c60"],[0.5555555555555556,"#cf4446"],[0.6666666666666666,"#ed6925"],[0.7777777777777778,"#fb9b06"],[0.8888888888888888,"#f7d13d"],[1.0,"#fcffa4"]],"hoverongaps":false,"text":[["1.0","0.38","0.36","0.34","0.25","0.16","0.11","0.13","0.18","-0.0","0.11","0.06"],["0.38","1.0","0.38","0.32","0.3","0.13","-0.0","0.15","0.19","-0.01","0.09","0.05"],["0.36","0.38","1.0","0.42","0.6","0.1","0.2","0.13","0.04","0.0","0.11","0.05"],["0.34","0.32","0.42","1.0","0.47","0.14","0.35","0.28","0.29","0.01","0.27","0.11"],["0.25","0.3","0.6","0.47","1.0","0.01","0.18","0.13","0.04","-0.01","0.11","0.03"],["0.16","0.13","0.1","0.14","0.01","1.0","0.09","-0.01","0.08","-0.02","0.04","-0.1"],["0.11","-0.0","0.2","0.35","0.18","0.09","1.0","0.43","0.05","0.06","0.28","0.13"],["0.13","0.15","0.13","0.28","0.13","-0.01","0.43","1.0","0.14","-0.0","0.18","0.22"],["0.18","0.19","0.04","0.29","0.04","0.08","0.05","0.14","1.0","0.03","0.15","0.08"],["-0.0","-0.01","0.0","0.01","-0.01","-0.02","0.06","-0.0","0.03","1.0","0.64","0.06"],["0.11","0.09","0.11","0.27","0.11","0.04","0.28","0.18","0.15","0.64","1.0","0.2"],["0.06","0.05","0.05","0.11","0.03","-0.1","0.13","0.22","0.08","0.06","0.2","1.0"]],"texttemplate":"%{text}","x":["PM2.5","PM10","NO","NO2","NOx","NH3","CO","SO2","O3","Benzene","Toluene","Xylene"],"y":["PM2.5","PM10","NO","NO2","NOx","NH3","CO","SO2","O3","Benzene","Toluene","Xylene"],"z":[[1.0,0.3806948604151851,0.3606602598292146,0.3408383640007723,0.25387258802192103,0.15555415755324148,0.10783407903784333,0.13491277233111432,0.18198298950594224,-0.004313774868675156,0.10848890884861384,0.06263049513720129],[0.3806948604151851,1.0,0.3817806679327817,0.3191491723818001,0.295864838772685,0.12676171993443075,-0.0021723428972432986,0.15340909055765675,0.18984107978169001,-0.006226284338240109,0.09291711734801286,0.05261524245718694],[0.3606602598292146,0.3817806679327817,1.0,0.4214680766748671,0.5954883499825404,0.09797299138410044,0.19622699620734968,0.13305624159229146,0.04331798569308482,0.0035584242283838697,0.10907716510944042,0.05266024720936355],[0.3408383640007723,0.3191491723818001,0.4214680766748671,1.0,0.4719723454670107,0.13536848500675222,0.3538245616201335,0.28349747450986656,0.2945529684495718,0.008305844816605358,0.27074057289678566,0.10695932248487011],[0.25387258802192103,0.295864838772685,0.5954883499825404,0.4719723454670107,1.0,0.012226468016435907,0.18100595861544205,0.1326536382468191,0.03842656593782295,-0.009989509424509158,0.10861096604727154,0.027929048422031283],[0.15555415755324148,0.12676171993443075,0.09797299138410044,0.13536848500675222,0.012226468016435907,1.0,0.08777175408374364,-0.012701901363942775,0.0766280163923904,-0.02366671879649253,0.04100943372871316,-0.09625151541637203],[0.10783407903784333,-0.0021723428972432986,0.19622699620734968,0.3538245616201335,0.18100595861544205,0.08777175408374364,1.0,0.4306751592134129,0.05408857449408635,0.057295277357967654,0.27680902237650534,0.12901212595816086],[0.13491277233111432,0.15340909055765675,0.13305624159229146,0.28349747450986656,0.1326536382468191,-0.012701901363942775,0.4306751592134129,1.0,0.142001852301198,-0.0035754464648048876,0.17698408178610908,0.2238085442881547],[0.18198298950594224,0.18984107978169001,0.04331798569308482,0.2945529684495718,0. ...

# %%
df['Date'] = pd.to_datetime(df['Date'],errors='coerce')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  datetime64[ns]
#  2   PM2.5       29531 non-null  float64
#  3   PM10        29531 non-null  float64
#  4   NO          29531 non-null  float64
#  5   NO2         29531 non-null  float64
#  6   NOx         29531 non-null  float64
#  7   NH3         29531 non-null  float64
#  8   CO          29531 non-null  float64
#  9   SO2         29531 non-null  float64
#  10  O3          29531 non-null  float64
#  11  Benzene     29531 non-null  float64
#  12  Toluene     29531 non-null  float64
#  13  Xylene      29531 non-null  float64
#  14  AQI         29531 non-null  float64
#  15  AQI_Bucket  29531 non-null  object
# dtypes: datetime64[ns](1), float64(13), object(2)
# memory usage: 3.6+ MB
# /tmp/ipython-input-2559210453.py:1: UserWarning:
#
# Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.

# %%
df['month'] = df['Date'].dt.month

# %%
def get_season(month):
    if 3 <= month <= 5:
        return 'Spring'
    elif 6 <= month <= 8:
        return 'Summer'
    elif 9 <= month <= 11:
        return 'Autumn'
    else:
        return 'Winter'
df['Season'] = df['month'].apply(get_season)

# %%
df.head()
# Out:
#     City       Date  PM2.5    PM10      NO    NO2     NOx    NH3    CO   SO2  \
# 0  Kochi 2020-01-22  46.54  113.87   21.86  84.84   99.99  27.89  1.25  7.01
# 1  Kochi 2020-01-23  62.48  110.34   22.08  55.67   73.57  25.35  1.33  6.48
# 2  Kochi 2020-01-24  62.87  114.86   37.44  60.49   97.80  25.60  1.44  6.91
# 3  Kochi 2020-01-25  61.76  113.70   92.78  67.73  160.51  22.11  1.34  6.68
# 4  Kochi 2020-01-26  66.76  113.24  106.79  58.69  165.49  20.70  1.36  6.75
#
#       O3  Benzene  Toluene  Xylene    AQI AQI_Bucket  month  Season
# 0  19.69     1.35     0.00    3.14  110.0   Moderate      1  Winter
# 1   9.54     1.35     0.00    3.14  110.0   Moderate      1  Winter
# 2   9.06     1.35     0.00    3.14  111.0   Moderate      1  Winter
# 3  11.29     1.35     0.00    3.14  144.0   Moderate      1  Winter
# 4  11.43     1.35     0.05    3.14  197.0   Moderate      1  Winter

# %%
# Group by season and calculate average pollutant concentrations
seasonal_avg = df.groupby('Season')[['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene']].mean().reset_index()

# Melt the DataFrame for visualization
seasonal_avg_melted = pd.melt(seasonal_avg, id_vars=['Season'], var_name='Pollutant', value_name='Average Concentration')

# Create a bar chart to visualize seasonal trends
fig = px.bar(seasonal_avg_melted,
             x='Season',
             y='Average Concentration',
             color='Pollutant',
             title='Average Pollutant Concentrations by Season',
             barmode='group')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="88a5e2b8-8db2-4713-900d-9c40bc64d461" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88a5e2b8-8db2-4713-900d-9c40bc64d461")) {                    Plotly.newPlot(                        "88a5e2b8-8db2-4713-900d-9c40bc64d461",                        [{"alignmentgroup":"True","hovertemplate":"Pollutant=PM2.5\u003cbr\u003eSeason=%{x}\u003cbr\u003eAverage Concentration=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PM2.5","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"PM2.5","offsetgroup":"PM2.5","orientation":"v","showlegend":true,"textposition":"auto","x":["Autumn","Spring","Summer","Winter"],"xaxis":"x","y":[71.02444628597257,56.820849854932305,40.930771372876634,92.8240309139785],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Pollutant=PM10\u003cbr\u003eSeason=%{x}\u003cbr\u003eAverage Concentration=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PM10","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"PM10","offsetgroup":"PM10","orientation":"v","showlegend":true,"textposition":"auto","x":["Autumn","Spring","Summer","Winter"],"xaxis":"x","y":[96.14557631459996,90.32428070599613,70.5100737956001,122.85932930107528],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Pollutant=NO\u003cbr\u003eSeason=%{x}\u003cbr\u003eAverage Concentration=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NO","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"NO","offsetgroup":"NO","orientation":"v","showlegend":true,"textposition":"auto","x":["Autumn","Spring","Summer","Winter"],"xaxis":"x","y":[19.028086484857617,15.568631528046422,11.454628237259817,22.550272849462367],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Pollutant=NO2\u003cbr\u003eSeason=%{x}\u003cbr\u003eAverage Concentration=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NO2","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"NO2","offsetgroup":"NO2","orientation":"v","showlegend":true,"textposition":"auto","x":["Autumn","Spring","Summer","Winter"],"xaxis":"x","y":[29.740846768118125,23.98796421663443,20.374554441659704,33.819456989247314],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Pollutant=NOx\u003cbr\u003eSeason=%{x}\u003cbr\u003eAverage Concentration=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NOx","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"NOx","offsetgroup":"NOx","orientation":"v","showlegend":true,"textposition":"auto","x":["Autumn","Spring","Summer","Winter"],"xaxis":"x","y":[37.5607714328763,28.856103723404257,24.79221665274297,42.59935887096774],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Pollutant=NH3\u003cbr\u003eSeason=%{x}\u003cbr\u003eAverage Concentration=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NH3","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"NH3","offsetgroup":"NH3","orientation":"v","showlegend":true,"textposition":"auto","x":["Autumn","Spring","Summer","Winter"],"xaxis":"x","y":[24.32024559288835,22.697351305609285,21.321979949874684,27.895629032258064],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Pollutant=CO\u003cbr\u003eSeason=%{x}\u003cbr\u003eAverage Concentration=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CO","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"CO","offsetgroup":"CO","orientation":"v","showlegend":true,"textposition":"auto","x":["Autumn","Spring","Summer","Winter"],"xaxis":"x","y":[2.5519948772035557,1.8524697775628625,2.034775828460039,2.799852150537635],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplat ...

# %%
import pandas as pd

# 1. Coordinates table
city_coords = pd.DataFrame({
    'City': [
        'Kochi','Bhopal','Lucknow','Kolkata','Guwahati','Amaravati','Aizawl',
        'Thiruvananthapuram','Jaipur','Ernakulam','Bengaluru','Mumbai','Hyderabad',
        'Patna','Talcher','Shillong','Coimbatore','Visakhapatnam','Chennai',
        'Gurugram','Brajrajnagar','Amritsar','Jorapokhar','Delhi','Chandigarh','Ahmedabad'
    ],
    'Latitude': [
        9.9312, 23.2599, 26.8467, 22.5726, 26.1445, 16.5062, 23.7271,
        8.5241, 26.9124, 9.9816, 12.9716, 19.0760, 17.3850,
        25.5941, 20.9485, 25.5788, 11.0168, 17.6868, 13.0827,
        28.4595, 21.8100, 31.6340, 23.7975, 28.7041, 30.7333, 23.0225
    ],
    'Longitude': [
        76.2673, 77.4126, 80.9462, 88.3639, 91.7362, 80.6480, 92.7176,
        76.9366, 75.7873, 76.2999, 77.5946, 72.8777, 78.4867,
        85.1376, 85.1950, 91.8933, 76.9558, 83.2185, 80.2707,
        77.0266, 83.1666, 74.8723, 86.1955, 77.1025, 76.7794, 72.5714
    ]
})

# %%
#Merge coordinates with your main df
df_map = df.merge(city_coords, on='City', how='left')

# %%
import folium

#Create summarized table per city for popup info
city_summary = df_map.groupby('City').agg({
    'AQI': 'mean',
    'PM2.5': 'mean',
    'PM10': 'mean'
}).reset_index()

city_summary = city_summary.merge(city_coords, on='City', how='left')

#Creating the map
center_lat = city_summary['Latitude'].mean()
center_lon = city_summary['Longitude'].mean()

m = folium.Map(location=[center_lat, center_lon], zoom_start=5)

colors = ['red','blue','green','purple','orange','darkblue',
          'pink','gray','black','lightblue','lightgreen','beige']

#Add markers with HTML popup
for i, row in city_summary.iterrows():

    popup_text = f"""
    <b>{row['City']}</b><br>
    Avg AQI: {row['AQI']:.1f}<br>
    Avg PM2.5: {row['PM2.5']:.1f}<br>
    Avg PM10: {row['PM10']:.1f}
    """

    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        tooltip=row['City'],
        popup=popup_text,
        icon=folium.Icon(color=colors[i % len(colors)])
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d0c4d2210c1c5ca7b1ce271cbfaddcfa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d0c4d2210c1c5ca7b1ce271cbfaddcfa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d0c4d2210c1c5ca7b1ce271cbfaddcfa = L.map(
#                 &quot;map_d0c4d2210c1c5ca7b1ce271cbfaddcfa&quot;,
#                 {
#                     center: [20.996442307692305, 80.63306923076924],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08c6a0333574ba7fbb80d685b1de1c8f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_08c6a0333574ba7fbb80d685b1de1c8f.addTo(map_d0c4d2210c1c5ca7b1ce271cbfaddcfa);
#
#
#             var marker_db75a89b005396bfba6174852a555f50 = L.marker(
#                 [23.0225, 72.5714],
#                 {
# }
#             ).addTo(map_d0c4d2210c1c5ca7b1ce271cbfaddcfa);
#
#
#             var icon_f0dc7201d8d900cfdea8d33aa27eb15c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7ce354fe36cf98590eb5ee58a931c47f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4a22e602a7db9aa5e3787464bc961e3 = $(`&lt;div id=&quot;html_e4a22e602a7db9aa5e3787464bc961e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Ahmedabad&lt;/b&gt;&lt;br&gt;     Avg AQI: 418.5&lt;br&gt;     Avg PM2.5: 92.4&lt;br&gt;     Avg PM10: 81.2     &lt;/div&gt;`)[0];
#                 popup_7ce354fe36cf98590eb5ee58a931c47f.setContent(html_e4a22e602a7db9aa5e3787464bc961e3);
#
#
#
#         marker_db75a89b005396bfba6174852a555f50.bindPopup(popup_7ce354fe36cf98590eb5ee58a931c47f)
#         ;
#
#
#
#
#             marker_db75a89b005396bfba6174852a555f50.bindTooltip(
#                 `&lt;div&gt;
#                      Ahmedabad
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_db75a89b005396bfba6174852a555f50.setIcon(icon_f0dc7201d8d900cfdea8d33aa27eb15c);
#
#
#             var marker_bab75b058498455d1a80333e7c5f1558 = L.marker(
#                 [23.7271, 92.7176],
#                 {
# }
#             ).addTo(map_d0c4d2210c1c5ca7b1ce271cbfaddcfa);
#
#
#             var icon_47026446aef02a14f671bc75758df6f4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_391f961c3ec264bac77b6b9dfb831501 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_889bc4e40f38ef0883319774b729214e = $(`&lt;div id=&quot;html_889bc4e40f38ef0883319774b729214e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Aizawl&lt;/b&gt;&lt;br&gt;     Avg AQI: 34.8&lt;br&gt;     Avg PM2.5: 16.9&lt;br&gt;     Avg PM10: 23.2     &lt;/div&gt;`)[0];
#                 popup_391f961c3ec264bac77b6b9dfb831501.setContent(html_889bc4e40f38ef0883319774b729214e);
#
#
#
#         marker_bab75b058498455d1a80333e7c5f1558.bindPopup(popup_391f961c3ec264bac77b6b9dfb831501)
#         ;
#
#
#
#
#             marker_bab75b058498455d1a80333e7c5f1558.bindTooltip(
#                 `&lt;div&gt;
#                      Aizawl
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_bab75b058498455d1a80333e7c5f1558.setIcon(icon_47026446aef02a14f671bc75758df6f4);
#
#
#             var marker_987f4ab2d6daa154614c3d93b848618c = L.marker(
#                 [16.5062, 80.648],
#                 {
# }
#             ).addTo(map_d0c4d2210c1c5ca7b1ce271cbfaddcfa);
#
#
#             var icon_a3e10edb29cd444f61ec335dce158f80 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_5d39a82896024c21c1c7cc4e4f47ecf6 = L.popup({
#   &quot;ma

# %% [markdown]
# AQI Bucket Distribution

# %%
df['AQI_Bucket'].value_counts().plot(kind='bar', figsize=(15.5,5), title='AQI Buckets')
# Out:
# <Axes: title={'center': 'AQI Buckets'}, xlabel='AQI_Bucket'>

# %%
df['AQI_Bucket'].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(14,14))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Boxplots for Outlier Detection

# %%
plt.figure(figsize=(16,12))
for i, col in enumerate(pollutants, 1):
    plt.subplot(4, 3, i)
    sns.boxplot(x=df[col])
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# Time-based EDA Month

# %%
monthly_mean = df.groupby('month')[pollutants].mean()
monthly_mean.plot(figsize=(15.5,6), title='Monthly Mean Pollution Levels')
# Out:
# <Axes: title={'center': 'Monthly Mean Pollution Levels'}, xlabel='month'>

# %% [markdown]
# Seasonal Pollutant Levels

# %%
seasonal_mean = df.groupby('Season')[pollutants].mean()
seasonal_mean.T.plot(kind='bar', figsize=(15.5,8), title="Pollutant Concentration by Season")
# Out:
# <Axes: title={'center': 'Pollutant Concentration by Season'}>

# %% [markdown]
# City-wise Pollution Levels

# %%
city_avg = df.groupby('City')[pollutants + ['AQI']].mean().sort_values(by='AQI', ascending=False)
city_avg.head()
# Out:
#                 PM2.5        PM10         NO        NO2        NOx        NH3  \
# City
# Ahmedabad   92.438074   81.245898  17.946491  47.434689  41.755495  36.630000
# Delhi      117.101215  233.949716  38.971533  50.769856  58.567023  41.957636
# Patna      115.883692   72.693412  29.574424  36.033703  44.754785  10.250484
# Gurugram   117.965182  106.248803  16.952704  22.731513  25.854390  32.993711
# Lucknow    105.185550   30.000000  15.129124  33.195256  23.391274  18.700906
#
#                   CO        SO2         O3   Benzene    Toluene    Xylene  \
# City
# Ahmedabad  17.782997  53.282220  38.936984  5.325326  24.226884  3.832494
# Delhi       1.976053  16.026446  50.816546  3.544480  17.185042  1.015037
# Patna       1.432099  20.247788  38.871668  1.509919   9.450108  4.903832
# Gurugram    1.243288   9.255902  33.288809  1.413794   4.544288  0.405581
# Lucknow     2.126904  12.032111  37.717332  3.515361   5.496730  3.140000
#
#                   AQI
# City
# Ahmedabad  418.490791
# Delhi      258.632653
# Patna      228.864909
# Gurugram   226.539011
# Lucknow    210.741663

# %% [markdown]
# Plot top polluted cities:

# %%
palette = sns.color_palette("tab10", len(city_avg))

plt.figure(figsize=(14,6))

plt.bar(
    range(len(city_avg)),
    city_avg["AQI"],
    color=palette,
    width=0.4
)

plt.xticks(range(len(city_avg)), city_avg.index, rotation=45, ha='right')

plt.title("Average AQI by City", fontsize=18, fontweight='bold')
plt.ylabel("Average AQI", fontsize=14)
plt.xlabel("City", fontsize=14)

plt.tight_layout()
plt.show()

# %% [markdown]
# Pollution Comparison Between Cities (Boxplots)

# %%
plt.figure(figsize=(15.5,6))
sns.boxplot(data=df, x="City", y="PM2.5")
plt.title("PM2.5 Variation by City", fontsize=18, fontweight='bold')
plt.xticks(rotation=45, ha='right')
plt.show()
